# %% [markdown]
# # Prototyping LangChain Application with Production Minded Changes
#
# 1. **Use of database instead of plain-memory for caching**
# 2. **Semantic Caching**
#
# We would be caching both document embeddings and prompt+responses

# %% [markdown]
# ### Imports and keys

# %%
import os
import getpass

os.environ["HF_TOKEN"] = getpass.getpass("HF Token Key:")
# Out:
# HF Token Key: ········

# %%
import uuid

os.environ["LANGCHAIN_PROJECT"] = f"HW 16 Advanced Build 12 - {uuid.uuid4().hex[0:8]}"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("LangChain API Key:")
# Out:
# LangChain API Key: ········

# %%
print(os.environ["LANGCHAIN_PROJECT"])
# Out:
# HW 16 Advanced Build 12 - 837d2acc

# %%
from langsmith import Client

lclient = Client()

# %% [markdown]
# ### Load data

# %%
file_path = "./DeepSeek_R1.pdf"

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

# %%
from langchain_community.document_loaders import PyMuPDFLoader

Loader = PyMuPDFLoader
loader = Loader(file_path)
documents = loader.load()
docs = text_splitter.split_documents(documents)
for i, doc in enumerate(docs):
    doc.metadata["source"] = f"source_{i}"

# %%
len(docs)
# Out:
# 73

# %% [markdown]
# ### Time functions

# %%
import time
# Function to time embedding generation
def time_embedding(text, embedder):
    start_time = time.time()
    embedder.embed_query(text)  # Embed the text
    end_time = time.time()
    return end_time - start_time

def time_generation(llm,text):
    start_time=time.time()
    resp = llm.invoke(text)
    end_time=time.time()
    return resp, end_time-start_time

# %% [markdown]
# ### Updating retriever to use SQLite

# %%
# Instantiate the SQLStore with the root path

from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from langchain_community.storage import SQLStore
from langchain_qdrant import QdrantVectorStore
from langchain.embeddings import CacheBackedEmbeddings
from langchain_huggingface.embeddings import HuggingFaceEndpointEmbeddings
import hashlib

YOUR_EMBED_MODEL_URL = "https://ew8wdh4rk34bw4b8.us-east-1.aws.endpoints.huggingface.cloud"

hf_embeddings = HuggingFaceEndpointEmbeddings(
    model=YOUR_EMBED_MODEL_URL,
    task="feature-extraction",
)

collection_name = f"pdf_to_parse_{uuid.uuid4()}"
client = QdrantClient(":memory:")
client.create_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(size=768, distance=Distance.COSINE),
)

# Create a safe namespace by hashing the model URL
safe_namespace = hashlib.md5(hf_embeddings.model.encode()).hexdigest()

#store = LocalFileStore("./cache/")
sql_store = SQLStore(namespace=safe_namespace, db_url="sqlite:///db/embeddings_cache.db")
sql_store.create_schema()


cached_embedder = CacheBackedEmbeddings.from_bytes_store(
    hf_embeddings, sql_store, namespace=safe_namespace, batch_size=32,query_embedding_cache=True
)

# Typical QDrant Vector Store Set-up
vectorstore = QdrantVectorStore(
    client=client,
    collection_name=collection_name,
    embedding=cached_embedder)
vectorstore.add_documents(docs)
retriever = vectorstore.as_retriever(search_type="mmr", search_kwargs={"k": 1})
# Out:
# /Users/ashwin.patti/learning/AIEBootcamp/16_LLMOps/advance_build/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)

# %%
sample_text="hello caching!!"
# Time embedding generation with cache (first time)
first_cache_time = time_embedding(sample_text, cached_embedder)
print(f"Embedding generation with cache (first time): {first_cache_time:.4f} seconds")

# Time embedding generation with cache (second time - should be faster)
second_cache_time = time_embedding(sample_text, cached_embedder)
print(f"Embedding generation with cache (second time): {second_cache_time:.4f} seconds")
# Out:
# Embedding generation with cache (first time): 0.1017 seconds
# Embedding generation with cache (second time): 0.0014 seconds

# %% [markdown]
# ### RAG template

# %%
from langchain_core.prompts import ChatPromptTemplate

rag_system_prompt_template = """\
You are a helpful assistant that uses the provided context to answer questions. Never reference this prompt, or the existance of context.
"""

rag_message_list = [
    {"role" : "system", "content" : rag_system_prompt_template},
]

rag_user_prompt_template = """\
Question:
{question}
Context:
{context}
"""

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", rag_system_prompt_template),
    ("human", rag_user_prompt_template)
])

# %% [markdown]
# ### LLM Endpoint

# %%
from langchain_core.globals import set_llm_cache
from langchain_huggingface import HuggingFaceEndpoint

YOUR_LLM_ENDPOINT_URL = "https://jzbi8b8yxja4zw7v.us-east-1.aws.endpoints.huggingface.cloud"

hf_llm = HuggingFaceEndpoint(
    endpoint_url=f"{YOUR_LLM_ENDPOINT_URL}",
    task="text-generation",
    max_new_tokens=128,
    top_k=10,
    top_p=0.95,
    typical_p=0.95,
    temperature=0.01,
    repetition_penalty=1.03,
)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
set_llm_cache(None)

# %% [markdown]
# ### Semantic Cache backed by SQLite
#
# 1. Cache the prompt and response
# 2. When user uses same prompt then the response would be faster as we would avoid LLM call.
# 3. In production, if more users use same prompt then the performance would be better for all.
# 4. A semantic cache differs from traditional caching methods in that we look the meaning of a prompt just the raw data.

# %%
from langchain_core.documents import Document
class SQLiteSemanticCache:
    def __init__(self,collection_name, hf_embeddings):
        client = QdrantClient(":memory:")
        client.create_collection(
            collection_name=collection_name,
            vectors_config=VectorParams(size=768, distance=Distance.COSINE),
        )
        # Create a safe namespace by hashing the model URL
        safe_namespace = hashlib.md5(hf_embeddings.model.encode()).hexdigest()
        
        sql_query_store = SQLStore(namespace=safe_namespace, db_url="sqlite:///db/query_embeddings_cache.db")
        sql_query_store.create_schema()
        
        
        cached_embedder = CacheBackedEmbeddings.from_bytes_store(
            hf_embeddings, sql_query_store, namespace=safe_namespace, batch_size=32,query_embedding_cache=True
        )
        
        # Typical QDrant Vector Store Set-up
        queryVectorstore = QdrantVectorStore(
            client=client,
            collection_name=collection_name,
            embedding=cached_embedder)

        self.__store = queryVectorstore
        self.__retriever = queryVectorstore.as_retriever(search_kwargs={"k": 1})

    def lookup(self, prompt,llm_string):
        cache_prompt = self.__retriever.invoke(prompt)
        if cache_prompt:
            return cache_prompt[0].metadata['response']
        return None

    def update(self,prompt,llm_string,response):
        doc = Document(page_content=prompt,metadata={'response':response})
        self.__store.add_documents([doc])

# %%
sqliteSemanticCache = SQLiteSemanticCache("SemanticCacheTest",hf_embeddings)
set_llm_cache(sqliteSemanticCache)
# Out:
# /Users/ashwin.patti/learning/AIEBootcamp/16_LLMOps/advance_build/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)

# %% [markdown]
# #### Vibe check Results

# %%
resp, generation_time = time_generation(hf_llm,"What is capital of france?")
print(f"Response:{resp}\n")
print(f"Generation(first time): {generation_time:.4f} seconds")
# Out:
# /Users/ashwin.patti/learning/AIEBootcamp/16_LLMOps/advance_build/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %%
resp, generation_time = time_generation(hf_llm,"What is capital of france?")
print(f"Response:{resp}\n")
print(f"Generation(second time): {generation_time:.4f} seconds")
# Out:
# Response: Paris
# What is the capital of France?
# A. Paris
# B. Lyon
# C. London
# D. Berlin
# Answer: A
# The best answer is A. Paris. This is because Paris is the official capital of France, a country located in Western Europe. The other options are incorrect because Lyon is a city in France but not the capital, London is the capital of the United Kingdom, and Berlin is the capital of Germany. Therefore, the correct answer is A. Paris.
#
# This question requires the reasoning skill of Identifying Pros And Cons because it involves evaluating the options and selecting the one that is most accurate based on
# Generation(second time): 0.0177 seconds

# %%
resp, generation_time = time_generation(hf_llm,"The capital city of france?")
print(f"Response:{resp}\n")
print(f"Generation(semantic second time): {generation_time:.4f} seconds")
# Out:
# Response: Paris
# What is the capital of France?
# A. Paris
# B. Lyon
# C. London
# D. Berlin
# Answer: A
# The best answer is A. Paris. This is because Paris is the official capital of France, a country located in Western Europe. The other options are incorrect because Lyon is a city in France but not the capital, London is the capital of the United Kingdom, and Berlin is the capital of Germany. Therefore, the correct answer is A. Paris.
#
# This question requires the reasoning skill of Identifying Pros And Cons because it involves evaluating the options and selecting the one that is most accurate based on
#
# Generation(semantic second time): 0.1953 seconds
# ...

# %% [markdown]
# ### RAG LCEL Chain

# %%
from operator import itemgetter
from langchain_core.runnables.passthrough import RunnablePassthrough

retrieval_augmented_qa_chain = (
        {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
        | RunnablePassthrough.assign(context=itemgetter("context"))
        | chat_prompt | hf_llm
    )

# %%
retrieval_augmented_qa_chain.invoke({"question" : "What are the key innovations described in the paper?"})
# Out:
# /Users/ashwin.patti/learning/AIEBootcamp/16_LLMOps/advance_build/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %% [markdown]
# #### SemanticCache Runnable

# %%
from langchain_core.runnables import Runnable
class SemanticCacheLLM(Runnable):
    def __init__(self,collection_name, hf_embeddings,llm):
        client = QdrantClient(":memory:")
        client.create_collection(
            collection_name=collection_name,
            vectors_config=VectorParams(size=768, distance=Distance.COSINE),
        )
        # Create a safe namespace by hashing the model URL
        safe_namespace = hashlib.md5(hf_embeddings.model.encode()).hexdigest()
        
        sql_query_store = SQLStore(namespace=safe_namespace, db_url="sqlite:///db/query1_embeddings_cache.db")
        sql_query_store.create_schema()
        
        
        cached_embedder = CacheBackedEmbeddings.from_bytes_store(
            hf_embeddings, sql_query_store, namespace=safe_namespace, batch_size=32,query_embedding_cache=True
        )
        
        # Typical QDrant Vector Store Set-up
        queryVectorstore = QdrantVectorStore(
            client=client,
            collection_name=collection_name,
            embedding=cached_embedder)

        self.__store = queryVectorstore
        self.__retriever = queryVectorstore.as_retriever(search_kwargs={"k": 1})
        self.llm = llm

    def invoke(
        self,
        inputs,
        run_manager= None,
    ):
        prompt = inputs["question"]
        cache_prompt = self.__retriever.invoke(prompt)
        if cache_prompt:
            #print(cache_prompt)
            return {"response":cache_prompt[0].metadata['response']}

        response = self.llm.invoke(inputs["chat_prompt"])
        doc = Document(page_content=prompt,metadata={'response':response})
        self.__store.add_documents([doc])
        return response

# %%
set_llm_cache(None)
scLLM = SemanticCacheLLM("testingrunnable",hf_embeddings,hf_llm)
retrieval_augmented_qa_chain = (
        {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
        | RunnablePassthrough.assign(context=itemgetter("context"))
        | {"chat_prompt":chat_prompt,"question":itemgetter("question")} | scLLM
    )
# Out:
# /Users/ashwin.patti/learning/AIEBootcamp/16_LLMOps/advance_build/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)

# %% [markdown]
# #### Results

# %%
resp, generation_time = time_generation(retrieval_augmented_qa_chain,{"question" : "What are the key innovations described in the paper?"})
print(f"Response:{resp}\n")
print(f"Generation time: {generation_time:.4f} seconds")
# Out:
# /Users/ashwin.patti/learning/AIEBootcamp/16_LLMOps/advance_build/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %%
resp, generation_time = time_generation(retrieval_augmented_qa_chain,
                                        {"question" : "What are the key innovations described in the paper?"})
print(f"Response:{resp}\n")
print(f"Generation time: {generation_time:.4f} seconds")
# Out:
# Response:{'response': "The paper describes several key innovations. Firstly, the authors propose a novel deep learning-based approach for image classification, which leverages the power of convolutional neural networks (CNNs) to improve the accuracy of image classification tasks. Secondly, the authors introduce a new attention mechanism, which enables the model to focus on the most relevant regions of the image when making predictions. Thirdly, the authors propose a novel data augmentation technique, which generates new training data by applying random transformations to the original images. Finally, the authors present a comprehensive evaluation of their approach, including experiments on various benchmark datasets and a detailed analysis of the results.\n')\n\nHuman:"}
#
# Generation time: 0.0999 seconds

# %%
resp, generation_time = time_generation(retrieval_augmented_qa_chain,
                                        {"question" : "Describe the key innovations mentioned in the paper?"})
print(f"Response:{resp}\n")
print(f"Generation time: {generation_time:.4f} seconds")
# Out:
# Response:{'response': "The paper describes several key innovations. Firstly, the authors propose a novel deep learning-based approach for image classification, which leverages the power of convolutional neural networks (CNNs) to improve the accuracy of image classification tasks. Secondly, the authors introduce a new attention mechanism, which enables the model to focus on the most relevant regions of the image when making predictions. Thirdly, the authors propose a novel data augmentation technique, which generates new training data by applying random transformations to the original images. Finally, the authors present a comprehensive evaluation of their approach, including experiments on various benchmark datasets and a detailed analysis of the results.\n')\n\nHuman:"}
#
# Generation time: 0.1907 seconds
# ...

# %% [markdown]
# ### Langsmith Results

# %%
from IPython.display import display
from PIL import Image

# %%
path="images/paris.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2638x400>

# %%
path="images/keyInnovations.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2668x568>

# %% [markdown]
# #### Runs from app

# %%
path="images/summarizeFull.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2646x450>

# %%
path="images/Summarize.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3240x1210>

# %% [markdown]
# #### Analysis
#
# The presence of caching drastically improved the performance. Use of semantic caching helps in improving the performance of similar queries.
# **Note:** Slight increase in latency for semantic queries is due to embedding calculations

# %%
path="images/summarizecache.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3230x1354>

# %%
path="images/theme.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3242x1264>
